# %% [markdown]
# # Validação SINAN vs info-saude
# Pré-requisito para hierarquia nacional futura.

# %%
from pathlib import Path
import sys
# Detecta dinamicamente a pasta raiz do projeto
BASE = Path('.').resolve()
sys.path.append(str(BASE))
sys.path.append(str(BASE / 'scripts'))
import executar_pipeline_completo as p

# %% [markdown]
# ## Validação 2017

# %%
resultado = p.validate_sinan_infosaude('familia_dengue')
resultado

# %% [markdown]
# ## Relatório

# %%
print(Path(p.SINAN_REPORT_MD).read_text(encoding='utf-8'))
