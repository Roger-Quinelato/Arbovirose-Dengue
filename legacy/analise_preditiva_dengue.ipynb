# %% [markdown]
# # Dengue DF - Análise e Modelagem
# Notebook gerado automaticamente pelo plano `plano_execucao_pipeline.md`.

# %%
from pathlib import Path
import sys
# Detecta dinamicamente a pasta raiz do projeto
BASE = Path('.').resolve()
sys.path.append(str(BASE))
sys.path.append(str(BASE / 'scripts'))
import executar_pipeline_completo as p

# %% [markdown]
# ## Seção 1 - Formalização do target

# %%
target_annual, target_decision = p.run_prompt1_target_analysis()
target_annual

# %% [markdown]
# ## Seções 2 a 5 - Limpeza, população, clima, sazonalidade e EDA

# %%
dataset = p.build_processed_dataset(target_decision['target_name'])
dataset.head()

# %% [markdown]
# ## Seção 6 - Rolling validation sem leakage

# %%
rolling = p.run_rolling_validation(dataset)
rolling

# %% [markdown]
# ## Seção 7 - Testes de ablação

# %%
ablation, winner = p.run_ablation_tests(dataset)
ablation

# %% [markdown]
# ## Seção 8 - Tuning

# %%
tuning, final_predictions = p.tune_models(dataset, winner['config'])
tuning.head()

# %% [markdown]
# ## Seção 9 - Visualizações e relatório final

# %%
p.make_final_visuals(dataset, winner, final_predictions)
print(Path(p.FINAL_REPORT_MD).read_text(encoding='utf-8')[:3000])
